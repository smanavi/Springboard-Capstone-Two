# %% [markdown]
# This notebook is messy and undocument, left here as an example of exploring the various aspects of a new-to-me package and API.

# %% [markdown]
# ### messy notebook for exploring the twitter api and its output

# %%
import tweepy
from datetime import datetime
from src.data import twitter_api_access
import pandas as pd
import os
import json

# %%
api = twitter_api_access.access_api()

# %%
care_about = ['created_at', 'id', 'text', 'retweet_count', 'reply_count', 'favorite_count']

# %%
keywords = '(#hiv OR #aids) lang:en place_country:US'

new_tweets = api.search_30_day(environment_name= '30dayArchive', 
                             query= keywords, 
#                              fromDate= start_date,
#                             toDate= '202101100000',
                            maxResults=100)

# %%
new_tweets_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(new_tweets):
    for col in care_about:
        new_tweets_df.at[n, col] = t.__getattribute__(col)

# %%
new_tweets_df.sort_values('favorite_count', ascending=False)
# Out:
#                    created_at                   id  \
# 30  2021-02-10 02:18:24+00:00  1359325816082083841
# 22  2021-02-10 12:49:58+00:00  1359484757353132035
# 78  2021-02-05 04:56:06+00:00  1357553562818125824
# 96  2021-01-31 23:32:16+00:00  1356022517408923650
# 86  2021-02-02 15:12:42+00:00  1356621573470498817
# ..                        ...                  ...
# 67  2021-02-06 20:09:49+00:00  1358145898266714114
# 68  2021-02-06 20:09:42+00:00  1358145868109647873
# 69  2021-02-06 15:43:28+00:00  1358078867399979013
# 28  2021-02-10 03:23:22+00:00  1359342166439464962
# 71  2021-02-06 01:14:53+00:00  1357860281712594945
#
#                                                  text retweet_count  \
# 30  When an #hiv doctor stress bakes. #UequalsU #P...             2
# 22  LOVE this article about Dr. Joe N’kolola and h...             4
# 78  How to turn your #enemy into your #firend! Fan...             1
# 96  $ENZC great DD 💥🤑 HIV? NO worries Enzolytics h...             1
# ...

# %%
keywords = '(#uequalsu OR #prep) lang:en place_country:US'

med_tweets = api.search_30_day(environment_name= '30dayArchive', 
                             query= keywords, 
#                              fromDate= start_date,
#                             toDate= '202101100000',
                            maxResults=100)

# %%
med_tweets_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(med_tweets):
    for col in care_about:
        med_tweets_df.at[n, col] = t.__getattribute__(col)

# %%
med_tweets_df.sort_values('favorite_count', ascending=False)
# Out:
#                    created_at                   id  \
# 10  2021-02-10 02:18:24+00:00  1359325816082083841
# 63  2021-02-01 11:47:51+00:00  1356207633829666818
# 48  2021-02-04 15:40:09+00:00  1357353256914141186
# 2   2021-02-11 05:20:33+00:00  1359734044989227014
# 59  2021-02-01 20:00:51+00:00  1356331699093831680
# ..                        ...                  ...
# 31  2021-02-06 11:45:02+00:00  1358018863456206849
# 30  2021-02-06 12:17:30+00:00  1358027035772354560
# 29  2021-02-06 12:35:53+00:00  1358031659959005184
# 72  2021-01-29 05:32:13+00:00  1355025936966692864
# 50  2021-02-03 20:40:58+00:00  1357066571609485313
#
#                                                  text retweet_count  \
# 10  When an #hiv doctor stress bakes. #UequalsU #P...             2
# 63  #MotivationMonday If you’re HIV+, getting to u...            10
# 48  #ThrowbackThursday to a time when HIV wasn’t p...             5
# 2   Visiting out of town. #Grindr #Hookup cute tow...             0
# ...

# %%
keywords = '(#hiv OR #aids) lang:en place_country:US'

new_tweets_2 = api.search_30_day(environment_name= '30dayArchive', 
                             query= keywords, 
#                              fromDate= start_date,
#                             toDate= '202101100000',
                            maxResults=100)

# %%
new_tweets_2_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(new_tweets_2):
    for col in care_about:
        new_tweets_2_df.at[n, col] = t.__getattribute__(col)

# %%
new_tweets_2_df.sort_values('favorite_count', ascending=False)
# Out:
#                    created_at                   id  \
# 30  2021-02-10 02:18:24+00:00  1359325816082083841
# 22  2021-02-10 12:49:58+00:00  1359484757353132035
# 78  2021-02-05 04:56:06+00:00  1357553562818125824
# 96  2021-01-31 23:32:16+00:00  1356022517408923650
# 86  2021-02-02 15:12:42+00:00  1356621573470498817
# ..                        ...                  ...
# 67  2021-02-06 20:09:49+00:00  1358145898266714114
# 68  2021-02-06 20:09:42+00:00  1358145868109647873
# 69  2021-02-06 15:43:28+00:00  1358078867399979013
# 28  2021-02-10 03:23:22+00:00  1359342166439464962
# 71  2021-02-06 01:14:53+00:00  1357860281712594945
#
#                                                  text retweet_count  \
# 30  When an #hiv doctor stress bakes. #UequalsU #P...             2
# 22  LOVE this article about Dr. Joe N’kolola and h...             4
# 78  How to turn your #enemy into your #firend! Fan...             1
# 96  $ENZC great DD 💥🤑 HIV? NO worries Enzolytics h...             1
# ...

# %%
keywords = '(#hiv OR #aids) lang:en place_country:US'

cursor = tweepy.Cursor(api.search_30_day,
                      environment_name='30dayArchive',
                      query= keywords,
#                       count=200
                      ).items(500)

# %%
cursor_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(cursor):
    for col in care_about:
        cursor_df.at[n, col] = t.__getattribute__(col)

# %%
cursor_df
# Out:
#                     created_at                   id  \
# 0    2021-02-11 23:37:23+00:00  1360010070633951239
# 1    2021-02-11 23:20:06+00:00  1360005723472752640
# 2    2021-02-11 18:52:03+00:00  1359938264300404740
# 3    2021-02-11 15:12:01+00:00  1359882891048546306
# 4    2021-02-11 14:58:20+00:00  1359879449412567041
# ..                         ...                  ...
# 172  2021-01-13 16:02:26+00:00  1349386333551173636
# 173  2021-01-13 15:37:07+00:00  1349379958490198019
# 174  2021-01-13 13:26:07+00:00  1349346993181782018
# 175  2021-01-13 13:14:09+00:00  1349343983382765568
# 176  2021-01-13 04:07:19+00:00  1349206367417102336
#
#                                                   text retweet_count  \
# 0    Sexy @BessEckstein joins in the new #TheMoreUC...             0
# 1    Great to see Trudie Elion in this excellent li...             0
# 2    According to the @CDC, from 2014 to 2018, HIV ...             0
# ...

# %%
cursor_df_2 = pd.DataFrame(columns=care_about)

for n,t in enumerate(cursor):
    for col in care_about:
        cursor_df_2.at[n, col] = t.__getattribute__(col)

# %%
cursor_df_2.sort_values('favorite_count', ascending=False)
# Out:
#                     created_at                   id  \
# 30   2021-02-10 02:18:24+00:00  1359325816082083841
# 134  2021-01-23 14:40:43+00:00  1352989643785064448
# 168  2021-01-14 16:39:24+00:00  1349758024282484744
# 22   2021-02-10 12:49:58+00:00  1359484757353132035
# 142  2021-01-22 19:11:01+00:00  1352695280236453888
# ..                         ...                  ...
# 41   2021-02-09 02:21:30+00:00  1358964208663027712
# 42   2021-02-09 01:43:19+00:00  1358954600808607744
# 43   2021-02-09 01:43:05+00:00  1358954540096081921
# 89   2021-02-02 00:47:02+00:00  1356403719391375360
# 125  2021-01-27 01:49:50+00:00  1354245198641958915
#
#                                                   text retweet_count  \
# 30   When an #hiv doctor stress bakes. #UequalsU #P...             2
# 134  This is me at 9 mos. Today is my 53rd birthday...             7
# 168  This week we started our buprenorphine program...             2
# ...

# %%
keywords = 'twitter'
test_cursor = tweepy.Cursor(api.search_30_day,
                      environment_name='30dayArchive',
                      query= keywords,
#                       count=200
                      ).items(500)

# %%
test_cursor_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(test_cursor):
    for col in care_about:
        test_cursor_df.at[n, col] = t.__getattribute__(col)

# %%
test_cursor_df
# Out:
#                     created_at                   id  \
# 0    2021-02-12 02:47:21+00:00  1360057880406347779
# 1    2021-02-12 02:47:21+00:00  1360057880402157577
# 2    2021-02-12 02:47:21+00:00  1360057880402083845
# 3    2021-02-12 02:47:21+00:00  1360057880397905927
# 4    2021-02-12 02:47:21+00:00  1360057880393752577
# ..                         ...                  ...
# 495  2021-02-12 02:47:21+00:00  1360057879173169157
# 496  2021-02-12 02:47:21+00:00  1360057879168974855
# 497  2021-02-12 02:47:21+00:00  1360057879168958468
# 498  2021-02-12 02:47:21+00:00  1360057879164833794
# 499  2021-02-12 02:47:21+00:00  1360057879164833792
#
#                                                   text retweet_count  \
# 0    RT @virginiahanusik: the world doesn’t deserve...             0
# 1    RT @CTMSALGADOFERN1: Leo hoy: “el gobierno est...             0
# 2              Amanhã tem jogo https://t.co/R2Y1w2Gg98             0
# ...

# %%
keywords = 'biden'
test_cursor = tweepy.Cursor(api.search,
                      q= keywords,
                      ).items(10)

# %%
test_cursor.next()
# Out:
# Status(_api=<tweepy.api.API object at 0x000001376E37D820>, _json={'created_at': 'Fri Feb 12 03:12:48 +0000 2021', 'id': 1360064282239639552, 'id_str': '1360064282239639552', 'text': 'RT @Noelleal: Gracias amantes de biden y otros pendejos en general', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Noelleal', 'name': 'Noel Alejandro Leal Rojas', 'id': 41220384, 'id_str': '41220384', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1349692152, 'id_str': '1349692152', 'name': 'Carlos La Roca', 'screen_name': 'LaRocaCarlosJ', 'location': 'Barquisimeto. Edo. Lara', 'description': 'Analista de Sistemas - UCLA. Locutor 
# ...

# %%
test_cursor.next()._json
# Out:
# {'created_at': 'Fri Feb 12 03:12:47 +0000 2021',
#  'id': 1360064280683421698,
#  'id_str': '1360064280683421698',
#  'text': 'RT @nicoleocobas: Jill Biden                                Joe Biden \n                             🤝\n\n                        “access” htt…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'nicoleocobas',
#     'name': 'Nicole Cobas',
#     'id': 1085279514840743937,
#     'id_str': '1085279514840743937',
#     'indices': [3, 16]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 3588672314,
#   'id_str': '3588672314',
#   'name': 'Original Zoltan Supports Unions',
# ...

# %%
test_cursor.num_tweets
# Out:
# 3

# %%
test_cursor.limit
# Out:
# 10

# %%
tweets = {}
for n,t in enumerate(test_cursor):
    tweets[n] = t._json

# %%
save_loc = r"C:\Users\smana\Documents\Springboard\springboard_git_dir\capstone2\data\raw"

# %%
test_json = os.path.join(save_loc, 'testing.json')

# %%
with open(test_json, 'w') as j:
    json.dump(tweets, j, indent=4)
    
j.close()

# %%
tweets
# Out:
# {0: {'created_at': 'Fri Feb 12 03:12:47 +0000 2021',
#   'id': 1360064279039401984,
#   'id_str': '1360064279039401984',
#   'text': "@MSNBC Wonder why this network is silent on Biden's call with China. Maybe because he's keeping the parameters that… https://t.co/mz8KddMQ10",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MSNBC',
#      'name': 'MSNBC',
#      'id': 2836421,
#      'id_str': '2836421',
#      'indices': [0, 6]}],
#    'urls': [{'url': 'https://t.co/mz8KddMQ10',
#      'expanded_url': 'https://twitter.com/i/web/status/1360064279039401984',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1360061583070814211,
#   'in_reply_to_status_id_str': '1360061583070814211',
# ...

# %%
for n, t in enumerate(test_cursor):
    print(t._json.keys())
#     print(t._json)
    print()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])
#
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])
#
# ...

# %%
test_cursor.next()
# Out:
# Status(_api=<tweepy.api.API object at 0x000001376E37D820>, _json={'created_at': 'Fri Feb 12 03:04:05 +0000 2021', 'id': 1360062090506088450, 'id_str': '1360062090506088450', 'text': 'RT @MaxKaiser75: Anímense! Cuando se elimina el populismo por la vía del voto y se gobierna para dar resultados y rendir cuentas, pasan cos…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'MaxKaiser75', 'name': 'Max Kaiser', 'id': 3264949920, 'id_str': '3264949920', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 814203571, 'id_str': '814203571', 'name': 'Miguel Angel Jimenez', 'screen_name': 'mickyjimenez23', 'location': 'México', '
# ...

# %%
x = 10
for n,t in enumerate(test_cursor):
    if n <= x:
        print(n, t._json)
# Out:
# 0 {'created_at': 'Fri Feb 12 03:03:18 +0000 2021', 'id': 1360061893268807680, 'id_str': '1360061893268807680', 'text': 'RT @briantylercohen: remember when Joe Biden was like “i’m not watching the trial i have more important things to focus on” and we were lik…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'briantylercohen', 'name': 'Brian Tyler Cohen', 'id': 455684839, 'id_str': '455684839', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 764533759, 'id_str': '764533759', 'name': 'I’m just a girl, oh little old me...', 'screen_name': '1desi_firangi', 'location': 'ShangriLa, SoCal', 'description': '@vp is my spir
# ...

# %%
cursor.pages
# Out:
# <bound method Cursor.pages of <tweepy.cursor.Cursor object at 0x0000013770DCA340>>

# %%
for item in cursor:
    print(item)

# %%
print(next(cursor.iterator))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-51-b9bc79f80163> in <module>
# ----> 1 print(next(cursor.iterator))
#
# ~\anaconda3\envs\capstone2\lib\site-packages\tweepy\cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~\anaconda3\envs\capstone2\lib\site-packages\tweepy\cursor.py in next(self)
#     204     def next(self):
#     205         if self.next_token == -1 or (self.limit and self.page_count == self.limit):
# --> 206             raise StopIteration
#     207         data = self.method(next=self.next_token, return_cursors=True, *self.args, **self.kwargs)
#     208         self.page_count += 1
#
# StopIteration:

# %%
for item in cursor.iterator:
    print(item)

# %%
for item in cursor.pages():
    print(item)

# %%
dir(cursor)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'items',
#  'iterator',
#  'pages']

# %%
cursor = tweepy.Cursor(api.friends, id=name, count=200)
for page in cursor.pages():
    for friend in page:

# %%
test_tweets = api.search_30_day(environment_name= '30dayArchive', 
                             query= 'twitter', 
#                              fromDate= start_date,
#                             toDate= '202101100000',
                            maxResults=10)

# %%
test_cursor

# %%
dir(test_tweets[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'filter_level',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'matching_rules',
#  'parse',
#  'parse_list',
#  'place',
#  'quote_count',
#  'reply_count',
#  'retweet',
#  'retweet_count',
# ...

# %% [markdown]
# ### use 30 day archive for testing keywords

# %%
keywords = (' "breath of the wild" lang:en')

new_tweets = api.search_30_day(environment_name= '30dayArchive', 
                             query= keywords, 
#                              fromDate= start_date,
                            toDate= '202101100000',
                            maxResults=100)

# %%
care_about = ['created_at', 'id', 'text', 'retweet_count', 'reply_count', 'favorite_count']

# %%
new_tweets_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(new_tweets):
    for col in care_about:
        new_tweets_df.at[n, col] = t.__getattribute__(col)

# %%
new_tweets_df
# Out:
#              created_at                   id  \
# 0   2021-01-09 23:59:50  1348056920477687808
# 1   2021-01-09 23:59:48  1348056911778775042
# 2   2021-01-09 23:59:09  1348056749425766400
# 3   2021-01-09 23:59:06  1348056738025582592
# 4   2021-01-09 23:57:24  1348056307841069057
# ..                  ...                  ...
# 95  2021-01-09 23:16:49  1348046095771951105
# 96  2021-01-09 23:15:59  1348045888195846144
# 97  2021-01-09 23:15:43  1348045820059406338
# 98  2021-01-09 23:15:12  1348045689801076739
# 99  2021-01-09 23:13:35  1348045281959571459
#
#                                                  text retweet_count  \
# 0   @BoundaryBreak Or give it the breath of the wi...             0
# 1   @NintendoAmerica you guys should start remakin...             0
# 2   Live now getting ready for the my dad plays ni...             0
# 3   RT @ThisSpoonyBard: When mom tells you we got ...             0
# 4                    @BrandyBeansH Breath of the Wild             0
# ...

# %% [markdown]
# ### use with caution -- only have a limited number of requests per month

# %%
tweets = api.search_full_archive(environment_name= 'fullArchive', 
                     query= search_words, 
                     fromDate= start_date,
                    toDate= end_date,
                    maxResults=10)

# %%
for t in tweets:
    print(t.geo)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
tweets_df = pd.DataFrame(columns=care_about)

for n,t in enumerate(tweets):
    for col in care_about:
        tweets_df.at[n, col] = t.__getattribute__(col)

# %%
tweets_df
# Out:
#             created_at                  id  \
# 0  2017-12-30 23:59:42  947255909444710412
# 1  2017-12-30 23:59:34  947255873390465024
# 2  2017-12-30 23:59:20  947255815362056193
# 3  2017-12-30 23:59:18  947255808668192768
# 4  2017-12-30 23:58:41  947255653776621569
# 5  2017-12-30 23:58:37  947255636600999936
# 6  2017-12-30 23:58:31  947255610994712576
# 7  2017-12-30 23:58:31  947255609732120577
# 8  2017-12-30 23:58:30  947255606687272961
# 9  2017-12-30 23:58:29  947255602190913541
#
#                                                 text
# 0  1. Undertale\n2. Xenoblade 1/2\n3. Zelda OoT/M...
# 1  Here, are my favourites from 2017!!\n\nZelda :...
# 2  6 DAY ZELDA CHARITY MARATHON! - Zeldathon Miss...
# 3  RT @Neil_Druckmann: 2017 was an incredible yea...
# 4  If you have a #Twitch account, love charities,...
# 5  Tôi đã thích video https://t.co/WV22KpbJ18 ZEL...
# 6  In depth interview with "The Legend of Zelda: ...
# 7         @hundmitklampfe Schon wieder neues Zelda ?
# ...

# %%
tweets[0].__getattribute__('text')
# Out:
# '1. Undertale\n2. Xenoblade 1/2\n3. Zelda OoT/MM\n4. Super Smash Bros Series.\n5. Super Mario Galaxy 1/2 https://t.co/kuFD1xYISs'

# %%
care_about = ['created_at', 'id', 'text']

# %%
tweets[0].user.__getattribute__('location')
# Out:
# 'Venezuela'

# %%
tweets[0].lang
# Out:
# 'de'

# %%
tweets[0].geo

# %%
tweets[0]._json
# Out:
# {'created_at': 'Sat Dec 30 23:59:42 +0000 2017',
#  'id': 947255909444710412,
#  'id_str': '947255909444710412',
#  'text': '1. Undertale\n2. Xenoblade 1/2\n3. Zelda OoT/MM\n4. Super Smash Bros Series.\n5. Super Mario Galaxy 1/2 https://t.co/kuFD1xYISs',
#  'display_text_range': [0, 99],
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2770437194,
#   'id_str': '2770437194',
#   'name': 'GARU',
#   'screen_name': 'GARU_Sw',
#   'location': 'Venezuela',
#   'url': None,
#   'description': 'Freelancer Web Developer and Translator. Video Game enthusiast\nBest Smash Bros Ultimate player in Venezuela.\n\n@Camichu1101 ❤️',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
# ...
